# %%
import cv2
import torch
from PIL import Image

# Model
# model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
model = torch.hub.load('yolov5-master', 'custom', path='best.pt', source='local') 


img = Image.open('test/bike2.jpg')

# Inference
results = model(img, size=370)  # includes NMS

# Results
results.print()  
results.show()
# results.show()  # or .show()

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]
# Out:
# F:\Anaconda\envs\pytorch_env\lib\site-packages\torchvision\io\image.py:11: UserWarning: Failed to load image Python extension: Could not find module 'F:\Anaconda\envs\pytorch_env\Lib\site-packages\torchvision\image.pyd' (or one of its dependencies). Try using the full path with constructor syntax.
#   warn(f"Failed to load image Python extension: {e}")
# YOLOv5  2022-2-12 torch 1.10.2 CUDA:0 (NVIDIA GeForce GTX 1060 3GB, 3072MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients
# Adding AutoShape...
# image 1/1: 600x960 3 Cyclists
# Speed: 13.0ms pre-process, 464.7ms inference, 6.0ms NMS per image at shape (1, 3, 256, 384)
#          xmin       ymin       xmax        ymax  confidence  class     name
# 0    5.858765   3.705006  438.86499  600.000000    0.805725      0  Cyclist
# 1  624.528442  28.872852  813.14093  588.162109    0.572550      0  Cyclist
# 2  416.936188   8.454857  621.17395  544.063171    0.459286      0  Cyclist

# %%
def draw_text(img, text,
          pos,
          font=cv2.FONT_HERSHEY_PLAIN,
          font_scale=1,
          font_thickness=1,
          text_color=(255, 255, 255),
          text_color_bg=(255, 0, 0)
          ):

    x, y = pos
    text_size, _ = cv2.getTextSize(text, font, font_scale, font_thickness)
    text_w, text_h = text_size
    cv2.rectangle(img, pos, (x + text_w, y + text_h), text_color_bg, -1)
    cv2.putText(img, text, (x, y + text_h + font_scale - 1), font, font_scale, text_color, font_thickness)

    return text_size

# %%
input_video_path = 'test/bikes.mp4'
output_video_path = 'bike_result_small_yolo.mp4'

cap = cv2.VideoCapture(input_video_path)


width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))  # float `width`
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
print(width, height, fps)
fourcc = cv2.VideoWriter_fourcc(*'MP4V')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    
    resized_frame = cv2.resize(frame, (370, 370), interpolation = cv2.INTER_AREA)
    results = model(resized_frame, size=370)

    for index, row in results.pandas().xyxy[0].iterrows():
        scale_x = width/370
        scale_y = height/370
        left  = int(row.xmin*scale_x)
        top = int(row.ymin*scale_y)
        right  = int(row.xmax*scale_x)
        bottom = int(row.ymax*scale_y)

        cv2.rectangle(frame, (left, top), (right, bottom), (255, 0, 0), 2)
        draw_text(frame, f"{row['name']} {round(row.confidence, 2)}", (left, top))
    out.write(frame)
    cv2.imshow('frame', frame)
    c = cv2.waitKey(1)
    if c & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 1280 720 29.97002997002997
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  179.430450  119.124718  234.816467  304.853699    0.576079      0  Cyclist
# 1  102.835327  185.300674  121.750061  237.448013    0.561207      0  Cyclist
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  184.545441  108.161926  238.270081  308.713257    0.489469      0  Cyclist
# 1   12.526475   41.356396  220.297256  366.771149    0.436318      0  Cyclist
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  192.078949  115.832146  238.928955  303.838104    0.605550      0  Cyclist
# 1   18.082079   44.028263  223.901367  368.343597    0.289525      0  Cyclist
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  196.365845  131.316055  242.050659  301.906677     0.48634      0  Cyclist
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  199.968048  135.779266  243.563095  298.520355    0.680447      0  Cyclist
# 1  334.780060  106.186943  369.524078  214.954971    0.509221      0  Cyclist
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  335.245361  108.096344  369.993591  213.483200    0.681089      0  Cyclist
# 1    0.713985  100.835419  101.607635  357.182526    0.261148      0  Cyclist
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  337.835815  111.004723  369.664215  213.376160    0.658395      0  Cyclist
# 1    0.000000   95.778000  106.368858  356.619324    0.434965      0  Cyclist
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  337.782806  112.185051  369.466064  212.097870    0.595423      0  Cyclist
# 1    0.037804   99.364014  105.756088  359.840881    0.475520      0  Cyclist
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0    0.065103  100.386086  108.535973  359.226196    0.385487      0  Cyclist
# 1  338.051727  112.142372  369.549438  212.314835    0.304851      0  Cyclist
#         xmin        ymin        xmax        ymax  confidence  class     name
# 0   0.000000  101.516655  111.515434  359.117340    0.431753      0  Cyclist
# 1  99.140282   45.466209  251.487183  368.359619    0.328717      0  Cyclist
#          xmin       ymin        xmax        ymax  confidence  class     name
# 0  100.884262  42.389790  255.893311  368.634827    0.333812      0  Cyclist
# 1    0.000000  98.051384  111.607231  358.494171    0.302148      0  Cyclist
#         xmin      ymin        xmax        ymax  confidence  class     name
# 0  101.62278  40.81464  238.648682  366.639618    0.426482      0  Cyclist
#         xmin       ymin        xmax   ymax  confidence  class     name
# 0  95.965759  38.318027  255.224701  370.0    0.381336      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#          xmin       ymin        xmax   ymax  confidence  class     name
# 0  114.939537  51.717407  269.430878  370.0    0.272339      0  Cyclist
#          xmin       ymin        xmax   ymax  confidence  class     name
# 0  188.097794  66.406815  298.961456  370.0    0.314569      0  Cyclist
#          xmin       ymin        xmax        ymax  confidence  class     name
# 0  164.615234  71.305038  303.274384  369.554321    0.719654      0  Cyclist
#          xmin      ymin       xmax   ymax  confidence  class     name
# 0  194.022171  73.35746  304.72818  370.0    0.671097      0  Cyclist
#         xmin       ymin        xmax       ymax  confidence  class     name
# 0  209.29628  79.894928  299.297913  368.96106    0.558401      0  Cyclist
#          xmin       ymin        xmax        ymax  confidence  class     name
# 0  216.032593  80.511681  296.909821  365.500214    0.426098      0  Cyclist
#          xmin       ymin        xmax        ymax  confidence  class     name
# 0  227.322113  83.932877  296.167023  366.510437    0.447236      0  Cyclist
#          xmin       ymin        xmax        ymax  confidence  class     name
# 0  224.764603  79.437859  298.387268  365.057312    0.311396      0  Cyclist
#          xmin       ymin        xmax        ymax  confidence  class     name
# 0  230.777832  83.009781  295.301086  365.151154    0.523219      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#         xmin       ymin      xmax        ymax  confidence  class     name
# 0  49.557838  11.554634  88.99437  149.197128     0.37851      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#         xmin      ymin        xmax        ymax  confidence  class     name
# 0  196.90242  7.095887  286.835754  345.417969    0.350817      0  Cyclist
#          xmin      ymin        xmax        ymax  confidence  class     name
# 0  197.497437  9.211044  286.638672  347.326416    0.325788      0  Cyclist
#          xmin      ymin       xmax        ymax  confidence  class     name
# 0  199.271729  9.639797  287.68335  336.804443    0.320745      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#          xmin       ymin        xmax        ymax  confidence  class     name
# 0  201.987946  39.701912  275.666534  347.771606    0.377841      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#    xmin       ymin      xmax       ymax  confidence  class     name
# 0   0.0  26.870405  6.840301  73.634605    0.256307      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#    xmin       ymin      xmax       ymax  confidence  class     name
# 0   0.0  26.915501  5.956309  70.986343    0.256275      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#    xmin       ymin      xmax       ymax  confidence  class     name
# 0   0.0  26.899942  5.829367  71.580849    0.253142      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  224.686951  105.163208  275.581451  237.019745    0.300705      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  284.802704  188.684998  303.148529  222.567596    0.262164      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#    xmin     ymin        xmax        ymax  confidence  class     name
# 0   0.0  0.39743  116.831688  194.871918     0.25575      0  Cyclist
#        xmin      ymin        xmax        ymax  confidence  class     name
# 0  1.656109  0.147231  130.873672  181.877655    0.394837      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#        xmin      ymin        xmax        ymax  confidence  class     name
# 0  2.802234  0.361931  112.170303  201.728424    0.324539      0  Cyclist
#        xmin  ymin        xmax        ymax  confidence  class     name
# 0  1.988554   0.0  108.663834  197.783768    0.425501      0  Cyclist
#         xmin      ymin        xmax        ymax  confidence  class     name
# 0   1.304533  1.085293  103.525238  200.483231    0.566772      0  Cyclist
# 1  24.926582  1.411769  160.824005  171.439102    0.279955      0  Cyclist
#        xmin  ymin        xmax        ymax  confidence  class     name
# 0  2.093703   0.0  100.853897  199.116394    0.420962      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#    xmin      ymin       xmax        ymax  confidence  class     name
# 0   0.0  4.392476  83.071754  250.376419    0.280194      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#          xmin      ymin        xmax        ymax  confidence  class     name
# 0  145.391602  6.781754  300.451904  255.861588    0.343428      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#          xmin  ymin        xmax        ymax  confidence  class     name
# 0  141.247345   0.0  275.105072  257.978516    0.618109      0  Cyclist
#          xmin  ymin        xmax        ymax  confidence  class     name
# 0  140.830627   0.0  276.241608  266.313629    0.321723      0  Cyclist
#          xmin      ymin        xmax        ymax  confidence  class     name
# 0  138.011719  0.314589  274.668335  275.485291    0.666336      0  Cyclist
#          xmin  ymin        xmax        ymax  confidence  class     name
# 0  141.775223   0.0  270.856689  276.563843    0.750768      0  Cyclist
#          xmin  ymin        xmax        ymax  confidence  class     name
# 0  136.531464   0.0  271.309845  278.503937    0.581417      0  Cyclist
#          xmin  ymin        xmax        ymax  confidence  class     name
# 0  136.613754   0.0  268.739105  279.271881    0.531209      0  Cyclist
#        xmin  ymin        xmax        ymax  confidence  class     name
# 0  134.7827   0.0  267.006836  274.662689    0.542037      0  Cyclist
#          xmin  ymin        xmax        ymax  confidence  class     name
# 0  136.582291   0.0  264.559814  270.259949    0.355264      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#          xmin  ymin        xmax        ymax  confidence  class     name
# 0  115.356552   0.0  256.734528  274.413696    0.336762      0  Cyclist
#          xmin  ymin        xmax        ymax  confidence  class     name
# 0  119.901947   0.0  250.889969  282.196899    0.282275      0  Cyclist
#          xmin  ymin        xmax        ymax  confidence  class     name
# 0  103.748482   0.0  245.303497  282.059509     0.30729      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#         xmin  ymin        xmax        ymax  confidence  class     name
# 0  92.444611   0.0  226.111542  240.061539     0.31437      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
#         xmin      ymin        xmax        ymax  confidence  class     name
# 0  75.588165  0.376383  216.041367  240.201981    0.286472      0  Cyclist
#         xmin      ymin        xmax        ymax  confidence  class     name
# 0  81.850616  0.418984  210.272324  244.797714     0.40862      0  Cyclist
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# ...
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# C:\Users\THEGOD~1\AppData\Local\Temp/ipykernel_11868/2857306000.py in <module>
#      14 while True:
#      15     ret, frame = cap.read()
# ---> 16     resized_frame = cv2.resize(frame, (370, 370), interpolation = cv2.INTER_AREA)
#      17     results = model(resized_frame, size=370)
#      18     print(results.pandas().xyxy[0])
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
